# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
# custom normalization 
class MyNormalization(nn.Module):
    def __init__(self):
        super(MyNormalization, self).__init__()
    
    def forward(self, x: torch.Tensor):
        mean = torch.mean(x, dim=0)
        std = torch.std(x, dim=0)
        return (x - mean)/std

# use MyNormalization instead of BatchNorm1d
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()

        # linear layer
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # batch normalization layer
        self.normal_01 = MyNormalization()
        self.normal_02 = MyNormalization()
        self.normal_03 = MyNormalization()
        self.normal_04 = MyNormalization()
        self.normal_05 = MyNormalization()
        self.normal_06 = MyNormalization()
        self.normal_07 = MyNormalization()

        # tinh chỉnh weight
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)
                nn.init.constant_(module.bias, 0.0)
            
    def forward(self, x):
        x = self.flatten(x)

        x = self.layer1(x)
        x = self.normal_01(x)
        x = F.sigmoid(x)

        x = self.layer2(x)
        x = self.normal_02(x)
        x = F.sigmoid(x)

        x = self.layer3(x)
        x = self.normal_03(x)
        x = F.sigmoid(x)

        x = self.layer4(x)
        x = self.normal_04(x)
        x = F.sigmoid(x)

        x = self.layer5(x)
        x = self.normal_05(x)
        x = F.sigmoid(x)

        x = self.layer6(x)
        x = self.normal_06(x)
        x = F.sigmoid(x)

        x = self.layer7(x)
        x = self.normal_07(x)
        x = F.sigmoid(x)

        x = self.output(x)
        return x

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr):
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=10, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(test_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 1.9214, Train_Acc: 0.5559, Validation Loss: 1.0067, Val_Acc: 0.6827, counter = 0
# EPOCH 2/100, Train_Loss: 1.5226, Train_Acc: 0.7091, Validation Loss: 0.8457, Val_Acc: 0.7148, counter = 0
# EPOCH 3/100, Train_Loss: 1.3055, Train_Acc: 0.7369, Validation Loss: 0.7398, Val_Acc: 0.7383, counter = 0
# EPOCH 4/100, Train_Loss: 1.1531, Train_Acc: 0.7610, Validation Loss: 0.6612, Val_Acc: 0.7595, counter = 0
# EPOCH 5/100, Train_Loss: 1.0380, Train_Acc: 0.7771, Validation Loss: 0.6009, Val_Acc: 0.7780, counter = 0
# EPOCH 6/100, Train_Loss: 0.9468, Train_Acc: 0.7884, Validation Loss: 0.5526, Val_Acc: 0.7897, counter = 0
# EPOCH 7/100, Train_Loss: 0.8739, Train_Acc: 0.7990, Validation Loss: 0.5141, Val_Acc: 0.7977, counter = 0
# EPOCH 8/100, Train_Loss: 0.8138, Train_Acc: 0.8073, Validation Loss: 0.4826, Val_Acc: 0.8053, counter = 0
# EPOCH 9/100, Train_Loss: 0.7656, Train_Acc: 0.8134, Validation Loss: 0.4552, Val_Acc: 0.8110, counter = 0
# EPOCH 10/100, Train_Loss: 0.7234, Train_Acc: 0.8184, Validation Loss: 0.4335, Val_Acc: 0.8162, counter = 0
# EPOCH 11/100, Train_Loss: 0.6879, Train_Acc: 0.8229, Validation Loss: 0.4145, Val_Acc: 0.8228, counter = 0
# EPOCH 12/100, Train_Loss: 0.6580, Train_Acc: 0.8277, Validation Loss: 0.3975, Val_Acc: 0.8252, counter = 0
# EPOCH 13/100, Train_Loss: 0.6324, Train_Acc: 0.8317, Validation Loss: 0.3828, Val_Acc: 0.8305, counter = 0
# EPOCH 14/100, Train_Loss: 0.6083, Train_Acc: 0.8354, Validation Loss: 0.3721, Val_Acc: 0.8320, counter = 0
# EPOCH 15/100, Train_Loss: 0.5876, Train_Acc: 0.8393, Validation Loss: 0.3599, Val_Acc: 0.8332, counter = 0
# EPOCH 16/100, Train_Loss: 0.5697, Train_Acc: 0.8412, Validation Loss: 0.3496, Val_Acc: 0.8382, counter = 0
# EPOCH 17/100, Train_Loss: 0.5529, Train_Acc: 0.8444, Validation Loss: 0.3424, Val_Acc: 0.8370, counter = 0
# EPOCH 18/100, Train_Loss: 0.5385, Train_Acc: 0.8474, Validation Loss: 0.3325, Val_Acc: 0.8397, counter = 0
# EPOCH 19/100, Train_Loss: 0.5246, Train_Acc: 0.8494, Validation Loss: 0.3265, Val_Acc: 0.8413, counter = 0
# EPOCH 20/100, Train_Loss: 0.5119, Train_Acc: 0.8515, Validation Loss: 0.3185, Val_Acc: 0.8448, counter = 0
# EPOCH 21/100, Train_Loss: 0.5003, Train_Acc: 0.8542, Validation Loss: 0.3132, Val_Acc: 0.8453, counter = 0
# EPOCH 22/100, Train_Loss: 0.4900, Train_Acc: 0.8564, Validation Loss: 0.3092, Val_Acc: 0.8455, counter = 0
# EPOCH 23/100, Train_Loss: 0.4798, Train_Acc: 0.8576, Validation Loss: 0.3046, Val_Acc: 0.8478, counter = 0
# EPOCH 24/100, Train_Loss: 0.4710, Train_Acc: 0.8596, Validation Loss: 0.2949, Val_Acc: 0.8528, counter = 0
# EPOCH 25/100, Train_Loss: 0.4620, Train_Acc: 0.8614, Validation Loss: 0.2932, Val_Acc: 0.8493, counter = 0
# EPOCH 26/100, Train_Loss: 0.4548, Train_Acc: 0.8628, Validation Loss: 0.2865, Val_Acc: 0.8558, counter = 0
# EPOCH 27/100, Train_Loss: 0.4469, Train_Acc: 0.8646, Validation Loss: 0.2811, Val_Acc: 0.8550, counter = 0
# EPOCH 28/100, Train_Loss: 0.4410, Train_Acc: 0.8650, Validation Loss: 0.2832, Val_Acc: 0.8522, counter = 1
# EPOCH 29/100, Train_Loss: 0.4322, Train_Acc: 0.8678, Validation Loss: 0.2745, Val_Acc: 0.8570, counter = 0
# EPOCH 30/100, Train_Loss: 0.4272, Train_Acc: 0.8689, Validation Loss: 0.2757, Val_Acc: 0.8542, counter = 1
# EPOCH 31/100, Train_Loss: 0.4221, Train_Acc: 0.8702, Validation Loss: 0.2696, Val_Acc: 0.8575, counter = 0
# EPOCH 32/100, Train_Loss: 0.4156, Train_Acc: 0.8720, Validation Loss: 0.2689, Val_Acc: 0.8595, counter = 0
# EPOCH 33/100, Train_Loss: 0.4101, Train_Acc: 0.8727, Validation Loss: 0.2721, Val_Acc: 0.8533, counter = 1
# EPOCH 34/100, Train_Loss: 0.4049, Train_Acc: 0.8740, Validation Loss: 0.2633, Val_Acc: 0.8638, counter = 0
# EPOCH 35/100, Train_Loss: 0.4004, Train_Acc: 0.8749, Validation Loss: 0.2575, Val_Acc: 0.8637, counter = 0
# EPOCH 36/100, Train_Loss: 0.3964, Train_Acc: 0.8761, Validation Loss: 0.2569, Val_Acc: 0.8620, counter = 0
# EPOCH 37/100, Train_Loss: 0.3903, Train_Acc: 0.8771, Validation Loss: 0.2566, Val_Acc: 0.8618, counter = 0
# EPOCH 38/100, Train_Loss: 0.3866, Train_Acc: 0.8780, Validation Loss: 0.2582, Val_Acc: 0.8592, counter = 1
# EPOCH 39/100, Train_Loss: 0.3826, Train_Acc: 0.8793, Validation Loss: 0.2556, Val_Acc: 0.8625, counter = 0
# EPOCH 40/100, Train_Loss: 0.3784, Train_Acc: 0.8812, Validation Loss: 0.2485, Val_Acc: 0.8677, counter = 0
# EPOCH 41/100, Train_Loss: 0.3746, Train_Acc: 0.8817, Validation Loss: 0.2529, Val_Acc: 0.8633, counter = 1
# EPOCH 42/100, Train_Loss: 0.3714, Train_Acc: 0.8830, Validation Loss: 0.2731, Val_Acc: 0.8477, counter = 2
# EPOCH 43/100, Train_Loss: 0.3677, Train_Acc: 0.8819, Validation Loss: 0.2503, Val_Acc: 0.8615, counter = 3
# EPOCH 44/100, Train_Loss: 0.3637, Train_Acc: 0.8845, Validation Loss: 0.2409, Val_Acc: 0.8688, counter = 0
# EPOCH 45/100, Train_Loss: 0.3606, Train_Acc: 0.8857, Validation Loss: 0.2403, Val_Acc: 0.8658, counter = 0
# EPOCH 46/100, Train_Loss: 0.3577, Train_Acc: 0.8857, Validation Loss: 0.2381, Val_Acc: 0.8677, counter = 0
# EPOCH 47/100, Train_Loss: 0.3546, Train_Acc: 0.8869, Validation Loss: 0.2366, Val_Acc: 0.8678, counter = 0
# EPOCH 48/100, Train_Loss: 0.3511, Train_Acc: 0.8875, Validation Loss: 0.2396, Val_Acc: 0.8653, counter = 1
# EPOCH 49/100, Train_Loss: 0.3480, Train_Acc: 0.8884, Validation Loss: 0.2431, Val_Acc: 0.8643, counter = 2
# EPOCH 50/100, Train_Loss: 0.3453, Train_Acc: 0.8883, Validation Loss: 0.2368, Val_Acc: 0.8677, counter = 3
# EPOCH 51/100, Train_Loss: 0.3436, Train_Acc: 0.8886, Validation Loss: 0.2332, Val_Acc: 0.8678, counter = 0
# EPOCH 52/100, Train_Loss: 0.3393, Train_Acc: 0.8902, Validation Loss: 0.2508, Val_Acc: 0.8535, counter = 1
# EPOCH 53/100, Train_Loss: 0.3383, Train_Acc: 0.8918, Validation Loss: 0.2327, Val_Acc: 0.8698, counter = 0
# EPOCH 54/100, Train_Loss: 0.3355, Train_Acc: 0.8923, Validation Loss: 0.2314, Val_Acc: 0.8685, counter = 0
# EPOCH 55/100, Train_Loss: 0.3312, Train_Acc: 0.8935, Validation Loss: 0.2382, Val_Acc: 0.8627, counter = 1
# EPOCH 56/100, Train_Loss: 0.3303, Train_Acc: 0.8926, Validation Loss: 0.2405, Val_Acc: 0.8638, counter = 2
# EPOCH 57/100, Train_Loss: 0.3265, Train_Acc: 0.8943, Validation Loss: 0.2314, Val_Acc: 0.8658, counter = 0
# EPOCH 58/100, Train_Loss: 0.3231, Train_Acc: 0.8953, Validation Loss: 0.2450, Val_Acc: 0.8592, counter = 1
# EPOCH 59/100, Train_Loss: 0.3211, Train_Acc: 0.8959, Validation Loss: 0.2253, Val_Acc: 0.8710, counter = 0
# EPOCH 60/100, Train_Loss: 0.3215, Train_Acc: 0.8948, Validation Loss: 0.2332, Val_Acc: 0.8642, counter = 1
# EPOCH 61/100, Train_Loss: 0.3180, Train_Acc: 0.8950, Validation Loss: 0.2250, Val_Acc: 0.8728, counter = 0
# EPOCH 62/100, Train_Loss: 0.3143, Train_Acc: 0.8982, Validation Loss: 0.2254, Val_Acc: 0.8718, counter = 1
# EPOCH 63/100, Train_Loss: 0.3114, Train_Acc: 0.8997, Validation Loss: 0.2308, Val_Acc: 0.8635, counter = 2
# EPOCH 64/100, Train_Loss: 0.3102, Train_Acc: 0.8983, Validation Loss: 0.2211, Val_Acc: 0.8717, counter = 0
# EPOCH 65/100, Train_Loss: 0.3084, Train_Acc: 0.9001, Validation Loss: 0.2251, Val_Acc: 0.8712, counter = 1
# EPOCH 66/100, Train_Loss: 0.3067, Train_Acc: 0.8991, Validation Loss: 0.2316, Val_Acc: 0.8695, counter = 2
# EPOCH 67/100, Train_Loss: 0.3043, Train_Acc: 0.9007, Validation Loss: 0.2189, Val_Acc: 0.8720, counter = 0
# EPOCH 68/100, Train_Loss: 0.3013, Train_Acc: 0.9013, Validation Loss: 0.2254, Val_Acc: 0.8717, counter = 1
# EPOCH 69/100, Train_Loss: 0.2997, Train_Acc: 0.9021, Validation Loss: 0.2290, Val_Acc: 0.8685, counter = 2
# EPOCH 70/100, Train_Loss: 0.2986, Train_Acc: 0.9019, Validation Loss: 0.2231, Val_Acc: 0.8737, counter = 3
# EPOCH 71/100, Train_Loss: 0.2966, Train_Acc: 0.9034, Validation Loss: 0.2251, Val_Acc: 0.8692, counter = 4
# EPOCH 72/100, Train_Loss: 0.2950, Train_Acc: 0.9024, Validation Loss: 0.2197, Val_Acc: 0.8728, counter = 5
# EPOCH 73/100, Train_Loss: 0.2936, Train_Acc: 0.9044, Validation Loss: 0.2189, Val_Acc: 0.8728, counter = 6
# EPOCH 74/100, Train_Loss: 0.2909, Train_Acc: 0.9042, Validation Loss: 0.2168, Val_Acc: 0.8720, counter = 0
# EPOCH 75/100, Train_Loss: 0.2878, Train_Acc: 0.9048, Validation Loss: 0.2175, Val_Acc: 0.8672, counter = 1
# EPOCH 76/100, Train_Loss: 0.2866, Train_Acc: 0.9059, Validation Loss: 0.2117, Val_Acc: 0.8758, counter = 0
# EPOCH 77/100, Train_Loss: 0.2843, Train_Acc: 0.9075, Validation Loss: 0.2224, Val_Acc: 0.8725, counter = 1
# EPOCH 78/100, Train_Loss: 0.2838, Train_Acc: 0.9073, Validation Loss: 0.2158, Val_Acc: 0.8742, counter = 2
# EPOCH 79/100, Train_Loss: 0.2804, Train_Acc: 0.9078, Validation Loss: 0.2162, Val_Acc: 0.8747, counter = 3
# EPOCH 80/100, Train_Loss: 0.2810, Train_Acc: 0.9081, Validation Loss: 0.2193, Val_Acc: 0.8737, counter = 4
# EPOCH 81/100, Train_Loss: 0.2789, Train_Acc: 0.9074, Validation Loss: 0.2223, Val_Acc: 0.8715, counter = 5
# EPOCH 82/100, Train_Loss: 0.2774, Train_Acc: 0.9096, Validation Loss: 0.2179, Val_Acc: 0.8732, counter = 6
# EPOCH 83/100, Train_Loss: 0.2740, Train_Acc: 0.9098, Validation Loss: 0.2282, Val_Acc: 0.8660, counter = 7
# EPOCH 84/100, Train_Loss: 0.2725, Train_Acc: 0.9107, Validation Loss: 0.2189, Val_Acc: 0.8723, counter = 8
# EPOCH 85/100, Train_Loss: 0.2692, Train_Acc: 0.9122, Validation Loss: 0.2141, Val_Acc: 0.8760, counter = 9
# Early Stopping at epoch 86, minimum = 0.22481929063796996

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.8643333333333333
