# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # relu có tính chất dead node cao, không nhận đầu vào âm -> giảm std (độ biến thiên) để giá trị đầu vào âm ít hơn. (1 -> 0.05)
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)               # thay đổi (normalization) các tham số trong weight matrix: std=1, mean=0
                nn.init.constant_(module.bias, 0.0)                             # điền hằng số vào trong weight matrix: bias là 0.0

    def forward(self, x):
        x = self.flatten(x)
        x = self.layer1(x)
        x = F.relu(x)
        x = self.layer2(x)
        x = F.relu(x)
        x = self.layer3(x)
        x = F.relu(x)
        x = self.layer4(x)
        x = F.relu(x)
        x = self.layer5(x)
        x = F.relu(x)
        x = self.layer6(x)
        x = F.relu(x)
        x = self.layer6(x)
        x = F.relu(x)
        x = self.layer7(x)
        x = F.relu(x)
        x = self.output(x)
        return x

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-3

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
# cơ chế học tự động learning rate
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr): 
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:    
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=10, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 1.1732, Train_Acc: 0.5358, Validation Loss: 0.7517, Val_Acc: 0.7433, counter = 0
# EPOCH 2/100, Train_Loss: 0.6420, Train_Acc: 0.7661, Validation Loss: 0.6003, Val_Acc: 0.7813, counter = 0
# EPOCH 3/100, Train_Loss: 0.5281, Train_Acc: 0.8088, Validation Loss: 0.5223, Val_Acc: 0.8168, counter = 0
# EPOCH 4/100, Train_Loss: 0.4802, Train_Acc: 0.8306, Validation Loss: 0.4635, Val_Acc: 0.8393, counter = 0
# EPOCH 5/100, Train_Loss: 0.4276, Train_Acc: 0.8491, Validation Loss: 0.4564, Val_Acc: 0.8375, counter = 0
# EPOCH 6/100, Train_Loss: 0.3947, Train_Acc: 0.8594, Validation Loss: 0.4116, Val_Acc: 0.8555, counter = 0
# EPOCH 7/100, Train_Loss: 0.3711, Train_Acc: 0.8674, Validation Loss: 0.4457, Val_Acc: 0.8483, counter = 1
# EPOCH 8/100, Train_Loss: 0.3485, Train_Acc: 0.8744, Validation Loss: 0.4801, Val_Acc: 0.8313, counter = 2
# EPOCH 9/100, Train_Loss: 0.3456, Train_Acc: 0.8759, Validation Loss: 0.3814, Val_Acc: 0.8693, counter = 0
# EPOCH 10/100, Train_Loss: 0.3205, Train_Acc: 0.8854, Validation Loss: 0.3488, Val_Acc: 0.8758, counter = 0
# EPOCH 11/100, Train_Loss: 0.3119, Train_Acc: 0.8878, Validation Loss: 0.3494, Val_Acc: 0.8768, counter = 1
# EPOCH 12/100, Train_Loss: 0.2988, Train_Acc: 0.8908, Validation Loss: 0.3798, Val_Acc: 0.8717, counter = 2
# EPOCH 13/100, Train_Loss: 0.2906, Train_Acc: 0.8952, Validation Loss: 0.3554, Val_Acc: 0.8723, counter = 3
# EPOCH 14/100, Train_Loss: 0.2821, Train_Acc: 0.8980, Validation Loss: 0.3573, Val_Acc: 0.8707, counter = 4
# EPOCH 15/100, Train_Loss: 0.2697, Train_Acc: 0.9011, Validation Loss: 0.3624, Val_Acc: 0.8687, counter = 5
# EPOCH 16/100, Train_Loss: 0.2705, Train_Acc: 0.9014, Validation Loss: 0.3927, Val_Acc: 0.8620, counter = 6
# EPOCH 17/100, Train_Loss: 0.2644, Train_Acc: 0.9022, Validation Loss: 0.3398, Val_Acc: 0.8785, counter = 0
# EPOCH 18/100, Train_Loss: 0.2528, Train_Acc: 0.9077, Validation Loss: 0.3548, Val_Acc: 0.8737, counter = 1
# EPOCH 19/100, Train_Loss: 0.2460, Train_Acc: 0.9086, Validation Loss: 0.3569, Val_Acc: 0.8802, counter = 2
# EPOCH 20/100, Train_Loss: 0.2347, Train_Acc: 0.9132, Validation Loss: 0.3485, Val_Acc: 0.8840, counter = 3
# EPOCH 21/100, Train_Loss: 0.2312, Train_Acc: 0.9147, Validation Loss: 0.3493, Val_Acc: 0.8822, counter = 4
# EPOCH 22/100, Train_Loss: 0.2284, Train_Acc: 0.9155, Validation Loss: 0.3435, Val_Acc: 0.8852, counter = 5
# EPOCH 23/100, Train_Loss: 0.2257, Train_Acc: 0.9168, Validation Loss: 0.3630, Val_Acc: 0.8830, counter = 6
# EPOCH 24/100, Train_Loss: 0.2124, Train_Acc: 0.9212, Validation Loss: 0.3630, Val_Acc: 0.8860, counter = 7
# EPOCH 25/100, Train_Loss: 0.2056, Train_Acc: 0.9240, Validation Loss: 0.3694, Val_Acc: 0.8783, counter = 8
# EPOCH 26/100, Train_Loss: 0.2134, Train_Acc: 0.9219, Validation Loss: 0.3580, Val_Acc: 0.8793, counter = 9
# EPOCH 27/100, Train_Loss: 0.2007, Train_Acc: 0.9262, Validation Loss: 0.3361, Val_Acc: 0.8867, counter = 0
# EPOCH 28/100, Train_Loss: 0.2016, Train_Acc: 0.9259, Validation Loss: 0.3735, Val_Acc: 0.8802, counter = 1
# EPOCH 29/100, Train_Loss: 0.1954, Train_Acc: 0.9286, Validation Loss: 0.3479, Val_Acc: 0.8860, counter = 2
# EPOCH 30/100, Train_Loss: 0.1920, Train_Acc: 0.9301, Validation Loss: 0.3569, Val_Acc: 0.8842, counter = 3
# EPOCH 31/100, Train_Loss: 0.1810, Train_Acc: 0.9332, Validation Loss: 0.4231, Val_Acc: 0.8703, counter = 4
# EPOCH 32/100, Train_Loss: 0.1854, Train_Acc: 0.9324, Validation Loss: 0.3658, Val_Acc: 0.8863, counter = 5
# EPOCH 33/100, Train_Loss: 0.1808, Train_Acc: 0.9334, Validation Loss: 0.3911, Val_Acc: 0.8813, counter = 6
# EPOCH 34/100, Train_Loss: 0.1708, Train_Acc: 0.9372, Validation Loss: 0.3681, Val_Acc: 0.8895, counter = 7
# EPOCH 35/100, Train_Loss: 0.1704, Train_Acc: 0.9374, Validation Loss: 0.3707, Val_Acc: 0.8843, counter = 8
# EPOCH 36/100, Train_Loss: 0.1661, Train_Acc: 0.9377, Validation Loss: 0.3850, Val_Acc: 0.8840, counter = 9
# Early Stopping at epoch 37, minimum = 0.37964164714018506

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.8841666666666667
