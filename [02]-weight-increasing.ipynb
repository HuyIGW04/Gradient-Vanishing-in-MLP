# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # khởi tạo trọng số lớn hơn để tăng gradient trong lan truyền ngược (std = 1.0)
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=1.0)               # thay đổi (normalization) các tham số trong weight matrix: std=1, mean=0
                nn.init.constant_(module.bias, 0.0)                             # điền hằng số vào trong weight matrix: bias là 0.0

    def forward(self, x):
        x = self.flatten(x)
        x = self.layer1(x)
        x = F.sigmoid(x)
        x = self.layer2(x)
        x = F.sigmoid(x)
        x = self.layer3(x)
        x = F.sigmoid(x)
        x = self.layer4(x)
        x = F.sigmoid(x)
        x = self.layer5(x)
        x = F.sigmoid(x)
        x = self.layer6(x)
        x = F.sigmoid(x)
        x = self.layer6(x)
        x = F.sigmoid(x)
        x = self.layer7(x)
        x = F.sigmoid(x)
        x = self.output(x)
        return x

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr):
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=3, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(test_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 4.0073, Train_Acc: 0.1533, Validation Loss: 1.3778, Val_Acc: 0.2152, counter = 0
# EPOCH 2/100, Train_Loss: 2.0542, Train_Acc: 0.2949, Validation Loss: 1.1599, Val_Acc: 0.3327, counter = 0
# EPOCH 3/100, Train_Loss: 1.8107, Train_Acc: 0.3810, Validation Loss: 1.0456, Val_Acc: 0.4007, counter = 0
# EPOCH 4/100, Train_Loss: 1.6554, Train_Acc: 0.4318, Validation Loss: 0.9710, Val_Acc: 0.4363, counter = 0
# EPOCH 5/100, Train_Loss: 1.5477, Train_Acc: 0.4651, Validation Loss: 0.9183, Val_Acc: 0.4602, counter = 0
# EPOCH 6/100, Train_Loss: 1.4675, Train_Acc: 0.4881, Validation Loss: 0.8768, Val_Acc: 0.4805, counter = 0
# EPOCH 7/100, Train_Loss: 1.4051, Train_Acc: 0.5076, Validation Loss: 0.8439, Val_Acc: 0.5022, counter = 0
# EPOCH 8/100, Train_Loss: 1.3524, Train_Acc: 0.5245, Validation Loss: 0.8156, Val_Acc: 0.5218, counter = 0
# EPOCH 9/100, Train_Loss: 1.3084, Train_Acc: 0.5395, Validation Loss: 0.7896, Val_Acc: 0.5365, counter = 0
# EPOCH 10/100, Train_Loss: 1.2691, Train_Acc: 0.5526, Validation Loss: 0.7679, Val_Acc: 0.5518, counter = 0
# EPOCH 11/100, Train_Loss: 1.2358, Train_Acc: 0.5641, Validation Loss: 0.7498, Val_Acc: 0.5608, counter = 0
# EPOCH 12/100, Train_Loss: 1.2050, Train_Acc: 0.5734, Validation Loss: 0.7326, Val_Acc: 0.5717, counter = 0
# EPOCH 13/100, Train_Loss: 1.1780, Train_Acc: 0.5809, Validation Loss: 0.7176, Val_Acc: 0.5782, counter = 0
# EPOCH 14/100, Train_Loss: 1.1534, Train_Acc: 0.5895, Validation Loss: 0.7044, Val_Acc: 0.5883, counter = 0
# EPOCH 15/100, Train_Loss: 1.1317, Train_Acc: 0.5971, Validation Loss: 0.6922, Val_Acc: 0.5972, counter = 0
# EPOCH 16/100, Train_Loss: 1.1111, Train_Acc: 0.6037, Validation Loss: 0.6813, Val_Acc: 0.6008, counter = 0
# EPOCH 17/100, Train_Loss: 1.0934, Train_Acc: 0.6096, Validation Loss: 0.6720, Val_Acc: 0.6083, counter = 0
# EPOCH 18/100, Train_Loss: 1.0763, Train_Acc: 0.6164, Validation Loss: 0.6623, Val_Acc: 0.6123, counter = 0
# EPOCH 19/100, Train_Loss: 1.0603, Train_Acc: 0.6220, Validation Loss: 0.6540, Val_Acc: 0.6155, counter = 0
# EPOCH 20/100, Train_Loss: 1.0454, Train_Acc: 0.6263, Validation Loss: 0.6461, Val_Acc: 0.6227, counter = 0
# EPOCH 21/100, Train_Loss: 1.0318, Train_Acc: 0.6306, Validation Loss: 0.6397, Val_Acc: 0.6267, counter = 0
# EPOCH 22/100, Train_Loss: 1.0191, Train_Acc: 0.6356, Validation Loss: 0.6323, Val_Acc: 0.6278, counter = 0
# EPOCH 23/100, Train_Loss: 1.0073, Train_Acc: 0.6390, Validation Loss: 0.6267, Val_Acc: 0.6310, counter = 0
# EPOCH 24/100, Train_Loss: 0.9960, Train_Acc: 0.6429, Validation Loss: 0.6206, Val_Acc: 0.6360, counter = 0
# EPOCH 25/100, Train_Loss: 0.9863, Train_Acc: 0.6453, Validation Loss: 0.6148, Val_Acc: 0.6365, counter = 0
# EPOCH 26/100, Train_Loss: 0.9758, Train_Acc: 0.6494, Validation Loss: 0.6091, Val_Acc: 0.6387, counter = 0
# EPOCH 27/100, Train_Loss: 0.9667, Train_Acc: 0.6517, Validation Loss: 0.6046, Val_Acc: 0.6387, counter = 0
# EPOCH 28/100, Train_Loss: 0.9583, Train_Acc: 0.6542, Validation Loss: 0.5997, Val_Acc: 0.6420, counter = 0
# EPOCH 29/100, Train_Loss: 0.9490, Train_Acc: 0.6574, Validation Loss: 0.5945, Val_Acc: 0.6430, counter = 0
# EPOCH 30/100, Train_Loss: 0.9415, Train_Acc: 0.6595, Validation Loss: 0.5902, Val_Acc: 0.6448, counter = 0
# EPOCH 31/100, Train_Loss: 0.9342, Train_Acc: 0.6628, Validation Loss: 0.5858, Val_Acc: 0.6472, counter = 0
# EPOCH 32/100, Train_Loss: 0.9271, Train_Acc: 0.6651, Validation Loss: 0.5824, Val_Acc: 0.6477, counter = 0
# EPOCH 33/100, Train_Loss: 0.9194, Train_Acc: 0.6668, Validation Loss: 0.5782, Val_Acc: 0.6510, counter = 0
# EPOCH 34/100, Train_Loss: 0.9125, Train_Acc: 0.6692, Validation Loss: 0.5742, Val_Acc: 0.6552, counter = 0
# EPOCH 35/100, Train_Loss: 0.9064, Train_Acc: 0.6708, Validation Loss: 0.5702, Val_Acc: 0.6585, counter = 0
# EPOCH 36/100, Train_Loss: 0.9005, Train_Acc: 0.6727, Validation Loss: 0.5667, Val_Acc: 0.6608, counter = 0
# EPOCH 37/100, Train_Loss: 0.8945, Train_Acc: 0.6751, Validation Loss: 0.5634, Val_Acc: 0.6605, counter = 0
# EPOCH 38/100, Train_Loss: 0.8882, Train_Acc: 0.6774, Validation Loss: 0.5603, Val_Acc: 0.6618, counter = 0
# EPOCH 39/100, Train_Loss: 0.8828, Train_Acc: 0.6800, Validation Loss: 0.5569, Val_Acc: 0.6618, counter = 0
# EPOCH 40/100, Train_Loss: 0.8768, Train_Acc: 0.6809, Validation Loss: 0.5539, Val_Acc: 0.6652, counter = 0
# EPOCH 41/100, Train_Loss: 0.8716, Train_Acc: 0.6829, Validation Loss: 0.5510, Val_Acc: 0.6643, counter = 0
# EPOCH 42/100, Train_Loss: 0.8667, Train_Acc: 0.6845, Validation Loss: 0.5482, Val_Acc: 0.6667, counter = 0
# EPOCH 43/100, Train_Loss: 0.8615, Train_Acc: 0.6856, Validation Loss: 0.5452, Val_Acc: 0.6715, counter = 0
# EPOCH 44/100, Train_Loss: 0.8560, Train_Acc: 0.6880, Validation Loss: 0.5425, Val_Acc: 0.6715, counter = 0
# EPOCH 45/100, Train_Loss: 0.8514, Train_Acc: 0.6894, Validation Loss: 0.5404, Val_Acc: 0.6723, counter = 0
# EPOCH 46/100, Train_Loss: 0.8473, Train_Acc: 0.6915, Validation Loss: 0.5369, Val_Acc: 0.6772, counter = 0
# EPOCH 47/100, Train_Loss: 0.8427, Train_Acc: 0.6929, Validation Loss: 0.5348, Val_Acc: 0.6780, counter = 0
# EPOCH 48/100, Train_Loss: 0.8381, Train_Acc: 0.6940, Validation Loss: 0.5320, Val_Acc: 0.6792, counter = 0
# EPOCH 49/100, Train_Loss: 0.8346, Train_Acc: 0.6964, Validation Loss: 0.5299, Val_Acc: 0.6832, counter = 0
# EPOCH 50/100, Train_Loss: 0.8301, Train_Acc: 0.6974, Validation Loss: 0.5274, Val_Acc: 0.6855, counter = 0
# EPOCH 51/100, Train_Loss: 0.8258, Train_Acc: 0.6997, Validation Loss: 0.5250, Val_Acc: 0.6867, counter = 0
# EPOCH 52/100, Train_Loss: 0.8224, Train_Acc: 0.7009, Validation Loss: 0.5235, Val_Acc: 0.6845, counter = 0
# EPOCH 53/100, Train_Loss: 0.8182, Train_Acc: 0.7021, Validation Loss: 0.5207, Val_Acc: 0.6875, counter = 0
# EPOCH 54/100, Train_Loss: 0.8139, Train_Acc: 0.7026, Validation Loss: 0.5188, Val_Acc: 0.6920, counter = 0
# EPOCH 55/100, Train_Loss: 0.8104, Train_Acc: 0.7048, Validation Loss: 0.5172, Val_Acc: 0.6932, counter = 0
# EPOCH 56/100, Train_Loss: 0.8072, Train_Acc: 0.7059, Validation Loss: 0.5151, Val_Acc: 0.6907, counter = 0
# EPOCH 57/100, Train_Loss: 0.8036, Train_Acc: 0.7069, Validation Loss: 0.5129, Val_Acc: 0.6933, counter = 0
# EPOCH 58/100, Train_Loss: 0.8004, Train_Acc: 0.7087, Validation Loss: 0.5109, Val_Acc: 0.6958, counter = 0
# EPOCH 59/100, Train_Loss: 0.7970, Train_Acc: 0.7091, Validation Loss: 0.5087, Val_Acc: 0.6978, counter = 0
# EPOCH 60/100, Train_Loss: 0.7940, Train_Acc: 0.7108, Validation Loss: 0.5072, Val_Acc: 0.6993, counter = 0
# EPOCH 61/100, Train_Loss: 0.7905, Train_Acc: 0.7115, Validation Loss: 0.5054, Val_Acc: 0.6992, counter = 0
# EPOCH 62/100, Train_Loss: 0.7872, Train_Acc: 0.7133, Validation Loss: 0.5039, Val_Acc: 0.7013, counter = 0
# EPOCH 63/100, Train_Loss: 0.7842, Train_Acc: 0.7139, Validation Loss: 0.5029, Val_Acc: 0.6992, counter = 0
# EPOCH 64/100, Train_Loss: 0.7816, Train_Acc: 0.7154, Validation Loss: 0.5005, Val_Acc: 0.7018, counter = 0
# EPOCH 65/100, Train_Loss: 0.7788, Train_Acc: 0.7161, Validation Loss: 0.4987, Val_Acc: 0.7040, counter = 0
# EPOCH 66/100, Train_Loss: 0.7758, Train_Acc: 0.7175, Validation Loss: 0.4973, Val_Acc: 0.7045, counter = 0
# EPOCH 67/100, Train_Loss: 0.7728, Train_Acc: 0.7181, Validation Loss: 0.4956, Val_Acc: 0.7058, counter = 0
# EPOCH 68/100, Train_Loss: 0.7705, Train_Acc: 0.7184, Validation Loss: 0.4947, Val_Acc: 0.7053, counter = 0
# EPOCH 69/100, Train_Loss: 0.7676, Train_Acc: 0.7192, Validation Loss: 0.4929, Val_Acc: 0.7080, counter = 0
# EPOCH 70/100, Train_Loss: 0.7653, Train_Acc: 0.7210, Validation Loss: 0.4912, Val_Acc: 0.7072, counter = 0
# EPOCH 71/100, Train_Loss: 0.7631, Train_Acc: 0.7223, Validation Loss: 0.4904, Val_Acc: 0.7082, counter = 0
# EPOCH 72/100, Train_Loss: 0.7600, Train_Acc: 0.7223, Validation Loss: 0.4883, Val_Acc: 0.7118, counter = 0
# EPOCH 73/100, Train_Loss: 0.7577, Train_Acc: 0.7244, Validation Loss: 0.4876, Val_Acc: 0.7097, counter = 0
# EPOCH 74/100, Train_Loss: 0.7555, Train_Acc: 0.7244, Validation Loss: 0.4864, Val_Acc: 0.7117, counter = 0
# EPOCH 75/100, Train_Loss: 0.7529, Train_Acc: 0.7257, Validation Loss: 0.4847, Val_Acc: 0.7128, counter = 0
# EPOCH 76/100, Train_Loss: 0.7513, Train_Acc: 0.7267, Validation Loss: 0.4833, Val_Acc: 0.7120, counter = 0
# EPOCH 77/100, Train_Loss: 0.7485, Train_Acc: 0.7277, Validation Loss: 0.4821, Val_Acc: 0.7120, counter = 0
# EPOCH 78/100, Train_Loss: 0.7462, Train_Acc: 0.7282, Validation Loss: 0.4808, Val_Acc: 0.7137, counter = 0
# EPOCH 79/100, Train_Loss: 0.7440, Train_Acc: 0.7295, Validation Loss: 0.4794, Val_Acc: 0.7132, counter = 0
# EPOCH 80/100, Train_Loss: 0.7416, Train_Acc: 0.7304, Validation Loss: 0.4783, Val_Acc: 0.7143, counter = 0
# EPOCH 81/100, Train_Loss: 0.7398, Train_Acc: 0.7304, Validation Loss: 0.4773, Val_Acc: 0.7162, counter = 0
# EPOCH 82/100, Train_Loss: 0.7379, Train_Acc: 0.7308, Validation Loss: 0.4765, Val_Acc: 0.7160, counter = 0
# EPOCH 83/100, Train_Loss: 0.7354, Train_Acc: 0.7319, Validation Loss: 0.4752, Val_Acc: 0.7170, counter = 0
# EPOCH 84/100, Train_Loss: 0.7337, Train_Acc: 0.7332, Validation Loss: 0.4737, Val_Acc: 0.7157, counter = 0
# EPOCH 85/100, Train_Loss: 0.7318, Train_Acc: 0.7342, Validation Loss: 0.4727, Val_Acc: 0.7157, counter = 0
# EPOCH 86/100, Train_Loss: 0.7302, Train_Acc: 0.7344, Validation Loss: 0.4720, Val_Acc: 0.7168, counter = 0
# EPOCH 87/100, Train_Loss: 0.7277, Train_Acc: 0.7349, Validation Loss: 0.4707, Val_Acc: 0.7175, counter = 0
# EPOCH 88/100, Train_Loss: 0.7256, Train_Acc: 0.7359, Validation Loss: 0.4697, Val_Acc: 0.7185, counter = 0
# EPOCH 89/100, Train_Loss: 0.7240, Train_Acc: 0.7374, Validation Loss: 0.4689, Val_Acc: 0.7170, counter = 0
# EPOCH 90/100, Train_Loss: 0.7222, Train_Acc: 0.7369, Validation Loss: 0.4679, Val_Acc: 0.7188, counter = 0
# EPOCH 91/100, Train_Loss: 0.7209, Train_Acc: 0.7375, Validation Loss: 0.4668, Val_Acc: 0.7193, counter = 0
# EPOCH 92/100, Train_Loss: 0.7188, Train_Acc: 0.7383, Validation Loss: 0.4657, Val_Acc: 0.7213, counter = 0
# EPOCH 93/100, Train_Loss: 0.7171, Train_Acc: 0.7388, Validation Loss: 0.4649, Val_Acc: 0.7227, counter = 0
# EPOCH 94/100, Train_Loss: 0.7148, Train_Acc: 0.7390, Validation Loss: 0.4640, Val_Acc: 0.7220, counter = 0
# EPOCH 95/100, Train_Loss: 0.7137, Train_Acc: 0.7406, Validation Loss: 0.4628, Val_Acc: 0.7202, counter = 0
# EPOCH 96/100, Train_Loss: 0.7115, Train_Acc: 0.7406, Validation Loss: 0.4623, Val_Acc: 0.7223, counter = 0
# EPOCH 97/100, Train_Loss: 0.7098, Train_Acc: 0.7418, Validation Loss: 0.4611, Val_Acc: 0.7232, counter = 0
# EPOCH 98/100, Train_Loss: 0.7081, Train_Acc: 0.7416, Validation Loss: 0.4603, Val_Acc: 0.7252, counter = 0
# EPOCH 99/100, Train_Loss: 0.7066, Train_Acc: 0.7431, Validation Loss: 0.4591, Val_Acc: 0.7250, counter = 0
# EPOCH 100/100, Train_Loss: 0.7051, Train_Acc: 0.7435, Validation Loss: 0.4587, Val_Acc: 0.7272, counter = 0

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.7271666666666666
