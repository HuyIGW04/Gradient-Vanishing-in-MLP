# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # relu có tính chất dead node cao, không nhận đầu vào âm -> giảm std (độ biến thiên) để giá trị đầu vào âm ít hơn. (1 -> 0.05)
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)               # thay đổi (normalization) các tham số trong weight matrix: std=1, mean=0
                nn.init.constant_(module.bias, 0.0)                             # điền hằng số vào trong weight matrix: bias là 0.0

    def forward(self, x):
        x = self.flatten(x)
        x = self.layer1(x)
        x = F.relu(x)
        x = self.layer2(x)
        x = F.relu(x)
        x = self.layer3(x)
        x = F.relu(x)
        x = self.layer4(x)
        x = F.relu(x)
        x = self.layer5(x)
        x = F.relu(x)
        x = self.layer6(x)
        x = F.relu(x)
        x = self.layer6(x)
        x = F.relu(x)
        x = self.layer7(x)
        x = F.relu(x)
        x = self.output(x)
        return x

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr):
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=3, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(test_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 2.3025, Train_Acc: 0.1058, Validation Loss: 1.3815, Val_Acc: 0.0995, counter = 0
# EPOCH 2/100, Train_Loss: 2.3024, Train_Acc: 0.1090, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 3/100, Train_Loss: 2.3024, Train_Acc: 0.1153, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 4/100, Train_Loss: 2.3024, Train_Acc: 0.1183, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 5/100, Train_Loss: 2.3023, Train_Acc: 0.1060, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 6/100, Train_Loss: 2.3023, Train_Acc: 0.1012, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 7/100, Train_Loss: 2.3023, Train_Acc: 0.1012, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 8/100, Train_Loss: 2.3023, Train_Acc: 0.1012, Validation Loss: 1.3815, Val_Acc: 0.0895, counter = 0
# EPOCH 9/100, Train_Loss: 2.3022, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 10/100, Train_Loss: 2.3022, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 11/100, Train_Loss: 2.3022, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 12/100, Train_Loss: 2.3021, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 13/100, Train_Loss: 2.3021, Train_Acc: 0.1175, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 14/100, Train_Loss: 2.3021, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 15/100, Train_Loss: 2.3021, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 16/100, Train_Loss: 2.3020, Train_Acc: 0.1012, Validation Loss: 1.3814, Val_Acc: 0.0895, counter = 0
# EPOCH 17/100, Train_Loss: 2.3020, Train_Acc: 0.1012, Validation Loss: 1.3813, Val_Acc: 0.0895, counter = 0
# EPOCH 18/100, Train_Loss: 2.3020, Train_Acc: 0.1012, Validation Loss: 1.3813, Val_Acc: 0.0895, counter = 0
# EPOCH 19/100, Train_Loss: 2.3019, Train_Acc: 0.1012, Validation Loss: 1.3813, Val_Acc: 0.0895, counter = 0
# EPOCH 20/100, Train_Loss: 2.3019, Train_Acc: 0.1012, Validation Loss: 1.3813, Val_Acc: 0.0895, counter = 0
# EPOCH 21/100, Train_Loss: 2.3018, Train_Acc: 0.1012, Validation Loss: 1.3813, Val_Acc: 0.0895, counter = 0
# EPOCH 22/100, Train_Loss: 2.3018, Train_Acc: 0.1012, Validation Loss: 1.3812, Val_Acc: 0.0895, counter = 0
# EPOCH 23/100, Train_Loss: 2.3018, Train_Acc: 0.1012, Validation Loss: 1.3812, Val_Acc: 0.0895, counter = 0
# EPOCH 24/100, Train_Loss: 2.3017, Train_Acc: 0.1012, Validation Loss: 1.3812, Val_Acc: 0.0895, counter = 0
# EPOCH 25/100, Train_Loss: 2.3017, Train_Acc: 0.1012, Validation Loss: 1.3811, Val_Acc: 0.0897, counter = 0
# EPOCH 26/100, Train_Loss: 2.3016, Train_Acc: 0.1171, Validation Loss: 1.3811, Val_Acc: 0.0895, counter = 0
# EPOCH 27/100, Train_Loss: 2.3015, Train_Acc: 0.1253, Validation Loss: 1.3811, Val_Acc: 0.0895, counter = 0
# EPOCH 28/100, Train_Loss: 2.3015, Train_Acc: 0.1012, Validation Loss: 1.3810, Val_Acc: 0.0895, counter = 0
# EPOCH 29/100, Train_Loss: 2.3014, Train_Acc: 0.1012, Validation Loss: 1.3810, Val_Acc: 0.0900, counter = 0
# EPOCH 30/100, Train_Loss: 2.3013, Train_Acc: 0.1245, Validation Loss: 1.3809, Val_Acc: 0.0912, counter = 0
# EPOCH 31/100, Train_Loss: 2.3012, Train_Acc: 0.1036, Validation Loss: 1.3809, Val_Acc: 0.0963, counter = 0
# EPOCH 32/100, Train_Loss: 2.3012, Train_Acc: 0.1364, Validation Loss: 1.3808, Val_Acc: 0.0948, counter = 0
# EPOCH 33/100, Train_Loss: 2.3011, Train_Acc: 0.1063, Validation Loss: 1.3808, Val_Acc: 0.1098, counter = 0
# EPOCH 34/100, Train_Loss: 2.3009, Train_Acc: 0.1108, Validation Loss: 1.3807, Val_Acc: 0.1157, counter = 0
# EPOCH 35/100, Train_Loss: 2.3008, Train_Acc: 0.1173, Validation Loss: 1.3806, Val_Acc: 0.1145, counter = 0
# EPOCH 36/100, Train_Loss: 2.3007, Train_Acc: 0.1270, Validation Loss: 1.3805, Val_Acc: 0.1205, counter = 0
# EPOCH 37/100, Train_Loss: 2.3005, Train_Acc: 0.1331, Validation Loss: 1.3805, Val_Acc: 0.1190, counter = 0
# EPOCH 38/100, Train_Loss: 2.3004, Train_Acc: 0.1389, Validation Loss: 1.3804, Val_Acc: 0.1308, counter = 0
# EPOCH 39/100, Train_Loss: 2.3002, Train_Acc: 0.1582, Validation Loss: 1.3802, Val_Acc: 0.1315, counter = 0
# EPOCH 40/100, Train_Loss: 2.3000, Train_Acc: 0.1475, Validation Loss: 1.3801, Val_Acc: 0.1382, counter = 0
# EPOCH 41/100, Train_Loss: 2.2997, Train_Acc: 0.1726, Validation Loss: 1.3800, Val_Acc: 0.1348, counter = 0
# EPOCH 42/100, Train_Loss: 2.2994, Train_Acc: 0.1649, Validation Loss: 1.3798, Val_Acc: 0.1443, counter = 0
# EPOCH 43/100, Train_Loss: 2.2991, Train_Acc: 0.1649, Validation Loss: 1.3796, Val_Acc: 0.1515, counter = 0
# EPOCH 44/100, Train_Loss: 2.2987, Train_Acc: 0.1676, Validation Loss: 1.3793, Val_Acc: 0.1573, counter = 0
# EPOCH 45/100, Train_Loss: 2.2983, Train_Acc: 0.1730, Validation Loss: 1.3790, Val_Acc: 0.1600, counter = 0
# EPOCH 46/100, Train_Loss: 2.2978, Train_Acc: 0.1769, Validation Loss: 1.3787, Val_Acc: 0.1608, counter = 0
# EPOCH 47/100, Train_Loss: 2.2971, Train_Acc: 0.1803, Validation Loss: 1.3783, Val_Acc: 0.1675, counter = 0
# EPOCH 48/100, Train_Loss: 2.2963, Train_Acc: 0.1869, Validation Loss: 1.3778, Val_Acc: 0.1795, counter = 0
# EPOCH 49/100, Train_Loss: 2.2954, Train_Acc: 0.1976, Validation Loss: 1.3771, Val_Acc: 0.1983, counter = 0
# EPOCH 50/100, Train_Loss: 2.2941, Train_Acc: 0.2394, Validation Loss: 1.3763, Val_Acc: 0.2192, counter = 0
# EPOCH 51/100, Train_Loss: 2.2925, Train_Acc: 0.2462, Validation Loss: 1.3752, Val_Acc: 0.2608, counter = 0
# EPOCH 52/100, Train_Loss: 2.2904, Train_Acc: 0.2796, Validation Loss: 1.3738, Val_Acc: 0.2987, counter = 0
# EPOCH 53/100, Train_Loss: 2.2876, Train_Acc: 0.2936, Validation Loss: 1.3718, Val_Acc: 0.2782, counter = 0
# EPOCH 54/100, Train_Loss: 2.2836, Train_Acc: 0.2706, Validation Loss: 1.3690, Val_Acc: 0.2537, counter = 0
# EPOCH 55/100, Train_Loss: 2.2779, Train_Acc: 0.2557, Validation Loss: 1.3649, Val_Acc: 0.2473, counter = 0
# EPOCH 56/100, Train_Loss: 2.2692, Train_Acc: 0.2535, Validation Loss: 1.3585, Val_Acc: 0.2400, counter = 0
# EPOCH 57/100, Train_Loss: 2.2551, Train_Acc: 0.2428, Validation Loss: 1.3478, Val_Acc: 0.2343, counter = 0
# EPOCH 58/100, Train_Loss: 2.2307, Train_Acc: 0.2353, Validation Loss: 1.3286, Val_Acc: 0.2232, counter = 0
# EPOCH 59/100, Train_Loss: 2.1846, Train_Acc: 0.2305, Validation Loss: 1.2903, Val_Acc: 0.2322, counter = 0
# EPOCH 60/100, Train_Loss: 2.0858, Train_Acc: 0.2534, Validation Loss: 1.2048, Val_Acc: 0.2210, counter = 0
# EPOCH 61/100, Train_Loss: 1.8939, Train_Acc: 0.2515, Validation Loss: 1.0786, Val_Acc: 0.2657, counter = 0
# EPOCH 62/100, Train_Loss: 1.7322, Train_Acc: 0.2080, Validation Loss: 1.0201, Val_Acc: 0.2033, counter = 0
# EPOCH 63/100, Train_Loss: 1.6689, Train_Acc: 0.2118, Validation Loss: 0.9906, Val_Acc: 0.2192, counter = 0
# EPOCH 64/100, Train_Loss: 1.5860, Train_Acc: 0.2978, Validation Loss: 0.9015, Val_Acc: 0.4065, counter = 0
# EPOCH 65/100, Train_Loss: 1.3934, Train_Acc: 0.4066, Validation Loss: 0.9601, Val_Acc: 0.3172, counter = 1
# EPOCH 66/100, Train_Loss: 1.3215, Train_Acc: 0.4226, Validation Loss: 0.7178, Val_Acc: 0.4548, counter = 0
# EPOCH 67/100, Train_Loss: 1.2524, Train_Acc: 0.4625, Validation Loss: 0.6879, Val_Acc: 0.5148, counter = 0
# EPOCH 68/100, Train_Loss: 1.2360, Train_Acc: 0.4869, Validation Loss: 0.6917, Val_Acc: 0.5340, counter = 1
# EPOCH 69/100, Train_Loss: 1.1554, Train_Acc: 0.5116, Validation Loss: 0.6547, Val_Acc: 0.5475, counter = 0
# EPOCH 70/100, Train_Loss: 1.1425, Train_Acc: 0.5273, Validation Loss: 0.6696, Val_Acc: 0.5303, counter = 1
# EPOCH 71/100, Train_Loss: 1.1336, Train_Acc: 0.5424, Validation Loss: 0.6539, Val_Acc: 0.5618, counter = 0
# EPOCH 72/100, Train_Loss: 1.1106, Train_Acc: 0.5616, Validation Loss: 0.6264, Val_Acc: 0.5600, counter = 0
# EPOCH 73/100, Train_Loss: 1.1154, Train_Acc: 0.5786, Validation Loss: 0.7003, Val_Acc: 0.5398, counter = 1
# EPOCH 74/100, Train_Loss: 1.0594, Train_Acc: 0.5849, Validation Loss: 0.6022, Val_Acc: 0.5723, counter = 0
# EPOCH 75/100, Train_Loss: 1.0954, Train_Acc: 0.5841, Validation Loss: 0.5859, Val_Acc: 0.6265, counter = 0
# EPOCH 76/100, Train_Loss: 1.0386, Train_Acc: 0.5967, Validation Loss: 0.5827, Val_Acc: 0.6053, counter = 0
# EPOCH 77/100, Train_Loss: 0.9678, Train_Acc: 0.6219, Validation Loss: 0.6434, Val_Acc: 0.5738, counter = 1
# EPOCH 78/100, Train_Loss: 1.0275, Train_Acc: 0.6060, Validation Loss: 0.5597, Val_Acc: 0.6678, counter = 0
# EPOCH 79/100, Train_Loss: 0.9589, Train_Acc: 0.6280, Validation Loss: 0.5577, Val_Acc: 0.6258, counter = 0
# EPOCH 80/100, Train_Loss: 0.9522, Train_Acc: 0.6304, Validation Loss: 0.6004, Val_Acc: 0.6583, counter = 1
# EPOCH 81/100, Train_Loss: 0.9662, Train_Acc: 0.6243, Validation Loss: 0.5373, Val_Acc: 0.6393, counter = 0
# EPOCH 82/100, Train_Loss: 0.9158, Train_Acc: 0.6434, Validation Loss: 0.5683, Val_Acc: 0.6403, counter = 1
# EPOCH 83/100, Train_Loss: 0.9323, Train_Acc: 0.6404, Validation Loss: 0.5140, Val_Acc: 0.6673, counter = 0
# EPOCH 84/100, Train_Loss: 0.8934, Train_Acc: 0.6534, Validation Loss: 0.5855, Val_Acc: 0.6253, counter = 1
# EPOCH 85/100, Train_Loss: 0.8973, Train_Acc: 0.6501, Validation Loss: 0.5240, Val_Acc: 0.6953, counter = 2
# Early Stopping at epoch 86, minimum = 0.5664885818958283

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.6261666666666666
