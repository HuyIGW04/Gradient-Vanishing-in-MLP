# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

        # tinh chỉnh tham số
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.05)
                nn.init.constant_(m.bias, 0.0)

    # add skip connection: 2 -> 4, 5 -> 8 
    def forward(self, x):
        x = self.flatten(x)

        x = self.layer1(x)
        x = F.sigmoid(x)
        
        skip = x                                  # save the information when moved layer 1
        x = self.layer2(x)
        x = F.sigmoid(x)    

        x = self.layer3(x)
        x = F.sigmoid(x)

        x = skip + x                              # add the infor (input of layer 2) to (input of layer 4) -> skip 3 
        x = self.layer4(x)
        x = F.sigmoid(x)
        
        skip = x                                  # save value: input of layer 5. 
        x = self.layer5(x)
        x = F.sigmoid(x)

        x = self.layer6(x)
        x = F.sigmoid(x)

        x = self.layer7(x)
        x = F.sigmoid(x)
        
        x = skip + x
        x = self.output(x)
        return x

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr):
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=10, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(test_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 2.3102, Train_Acc: 0.0997, Validation Loss: 1.3816, Val_Acc: 0.1615, counter = 0
# EPOCH 2/100, Train_Loss: 2.3003, Train_Acc: 0.1211, Validation Loss: 1.3798, Val_Acc: 0.1597, counter = 0
# EPOCH 3/100, Train_Loss: 2.2978, Train_Acc: 0.1292, Validation Loss: 1.3781, Val_Acc: 0.1113, counter = 0
# EPOCH 4/100, Train_Loss: 2.2953, Train_Acc: 0.1469, Validation Loss: 1.3761, Val_Acc: 0.1700, counter = 0
# EPOCH 5/100, Train_Loss: 2.2926, Train_Acc: 0.1465, Validation Loss: 1.3749, Val_Acc: 0.1325, counter = 0
# EPOCH 6/100, Train_Loss: 2.2899, Train_Acc: 0.1736, Validation Loss: 1.3726, Val_Acc: 0.1028, counter = 0
# EPOCH 7/100, Train_Loss: 2.2868, Train_Acc: 0.1906, Validation Loss: 1.3712, Val_Acc: 0.2498, counter = 0
# EPOCH 8/100, Train_Loss: 2.2834, Train_Acc: 0.2159, Validation Loss: 1.3698, Val_Acc: 0.1740, counter = 0
# EPOCH 9/100, Train_Loss: 2.2799, Train_Acc: 0.2191, Validation Loss: 1.3671, Val_Acc: 0.1970, counter = 0
# EPOCH 10/100, Train_Loss: 2.2757, Train_Acc: 0.2586, Validation Loss: 1.3647, Val_Acc: 0.1007, counter = 0
# EPOCH 11/100, Train_Loss: 2.2710, Train_Acc: 0.2611, Validation Loss: 1.3617, Val_Acc: 0.2662, counter = 0
# EPOCH 12/100, Train_Loss: 2.2660, Train_Acc: 0.2711, Validation Loss: 1.3584, Val_Acc: 0.2457, counter = 0
# EPOCH 13/100, Train_Loss: 2.2600, Train_Acc: 0.2822, Validation Loss: 1.3536, Val_Acc: 0.2545, counter = 0
# EPOCH 14/100, Train_Loss: 2.2530, Train_Acc: 0.3218, Validation Loss: 1.3501, Val_Acc: 0.3095, counter = 0
# EPOCH 15/100, Train_Loss: 2.2449, Train_Acc: 0.3450, Validation Loss: 1.3447, Val_Acc: 0.4013, counter = 0
# EPOCH 16/100, Train_Loss: 2.2353, Train_Acc: 0.3541, Validation Loss: 1.3386, Val_Acc: 0.3025, counter = 0
# EPOCH 17/100, Train_Loss: 2.2239, Train_Acc: 0.3749, Validation Loss: 1.3319, Val_Acc: 0.2162, counter = 0
# EPOCH 18/100, Train_Loss: 2.2104, Train_Acc: 0.3627, Validation Loss: 1.3223, Val_Acc: 0.3452, counter = 0
# EPOCH 19/100, Train_Loss: 2.1942, Train_Acc: 0.3594, Validation Loss: 1.3122, Val_Acc: 0.3755, counter = 0
# EPOCH 20/100, Train_Loss: 2.1750, Train_Acc: 0.3709, Validation Loss: 1.2998, Val_Acc: 0.3523, counter = 0
# EPOCH 21/100, Train_Loss: 2.1522, Train_Acc: 0.3708, Validation Loss: 1.2852, Val_Acc: 0.2802, counter = 0
# EPOCH 22/100, Train_Loss: 2.1255, Train_Acc: 0.3761, Validation Loss: 1.2676, Val_Acc: 0.2898, counter = 0
# EPOCH 23/100, Train_Loss: 2.0945, Train_Acc: 0.3799, Validation Loss: 1.2490, Val_Acc: 0.3147, counter = 0
# EPOCH 24/100, Train_Loss: 2.0592, Train_Acc: 0.3863, Validation Loss: 1.2264, Val_Acc: 0.4943, counter = 0
# EPOCH 25/100, Train_Loss: 2.0206, Train_Acc: 0.3884, Validation Loss: 1.2025, Val_Acc: 0.3835, counter = 0
# EPOCH 26/100, Train_Loss: 1.9792, Train_Acc: 0.3806, Validation Loss: 1.1774, Val_Acc: 0.4137, counter = 0
# EPOCH 27/100, Train_Loss: 1.9368, Train_Acc: 0.3931, Validation Loss: 1.1528, Val_Acc: 0.3948, counter = 0
# EPOCH 28/100, Train_Loss: 1.8950, Train_Acc: 0.4038, Validation Loss: 1.1284, Val_Acc: 0.3873, counter = 0
# EPOCH 29/100, Train_Loss: 1.8543, Train_Acc: 0.4090, Validation Loss: 1.1049, Val_Acc: 0.4038, counter = 0
# EPOCH 30/100, Train_Loss: 1.8167, Train_Acc: 0.4167, Validation Loss: 1.0834, Val_Acc: 0.4588, counter = 0
# EPOCH 31/100, Train_Loss: 1.7814, Train_Acc: 0.4229, Validation Loss: 1.0635, Val_Acc: 0.4512, counter = 0
# EPOCH 32/100, Train_Loss: 1.7490, Train_Acc: 0.4456, Validation Loss: 1.0454, Val_Acc: 0.4303, counter = 0
# EPOCH 33/100, Train_Loss: 1.7188, Train_Acc: 0.4537, Validation Loss: 1.0284, Val_Acc: 0.3985, counter = 0
# EPOCH 34/100, Train_Loss: 1.6906, Train_Acc: 0.4546, Validation Loss: 1.0118, Val_Acc: 0.4313, counter = 0
# EPOCH 35/100, Train_Loss: 1.6642, Train_Acc: 0.4632, Validation Loss: 0.9958, Val_Acc: 0.4417, counter = 0
# EPOCH 36/100, Train_Loss: 1.6390, Train_Acc: 0.4729, Validation Loss: 0.9809, Val_Acc: 0.4702, counter = 0
# EPOCH 37/100, Train_Loss: 1.6142, Train_Acc: 0.4818, Validation Loss: 0.9667, Val_Acc: 0.4480, counter = 0
# EPOCH 38/100, Train_Loss: 1.5901, Train_Acc: 0.4870, Validation Loss: 0.9527, Val_Acc: 0.4730, counter = 0
# EPOCH 39/100, Train_Loss: 1.5663, Train_Acc: 0.4939, Validation Loss: 0.9386, Val_Acc: 0.4935, counter = 0
# EPOCH 40/100, Train_Loss: 1.5426, Train_Acc: 0.5055, Validation Loss: 0.9245, Val_Acc: 0.5107, counter = 0
# EPOCH 41/100, Train_Loss: 1.5191, Train_Acc: 0.5146, Validation Loss: 0.9120, Val_Acc: 0.4788, counter = 0
# EPOCH 42/100, Train_Loss: 1.4963, Train_Acc: 0.5207, Validation Loss: 0.8980, Val_Acc: 0.4955, counter = 0
# EPOCH 43/100, Train_Loss: 1.4733, Train_Acc: 0.5258, Validation Loss: 0.8845, Val_Acc: 0.5028, counter = 0
# EPOCH 44/100, Train_Loss: 1.4508, Train_Acc: 0.5338, Validation Loss: 0.8703, Val_Acc: 0.5313, counter = 0
# EPOCH 45/100, Train_Loss: 1.4288, Train_Acc: 0.5424, Validation Loss: 0.8589, Val_Acc: 0.5258, counter = 0
# EPOCH 46/100, Train_Loss: 1.4075, Train_Acc: 0.5473, Validation Loss: 0.8454, Val_Acc: 0.5360, counter = 0
# EPOCH 47/100, Train_Loss: 1.3869, Train_Acc: 0.5564, Validation Loss: 0.8332, Val_Acc: 0.5518, counter = 0
# EPOCH 48/100, Train_Loss: 1.3669, Train_Acc: 0.5579, Validation Loss: 0.8218, Val_Acc: 0.5613, counter = 0
# EPOCH 49/100, Train_Loss: 1.3477, Train_Acc: 0.5663, Validation Loss: 0.8107, Val_Acc: 0.5387, counter = 0
# EPOCH 50/100, Train_Loss: 1.3288, Train_Acc: 0.5686, Validation Loss: 0.7995, Val_Acc: 0.5542, counter = 0
# EPOCH 51/100, Train_Loss: 1.3110, Train_Acc: 0.5707, Validation Loss: 0.7898, Val_Acc: 0.5727, counter = 0
# EPOCH 52/100, Train_Loss: 1.2939, Train_Acc: 0.5761, Validation Loss: 0.7805, Val_Acc: 0.5752, counter = 0
# EPOCH 53/100, Train_Loss: 1.2778, Train_Acc: 0.5820, Validation Loss: 0.7703, Val_Acc: 0.5620, counter = 0
# EPOCH 54/100, Train_Loss: 1.2617, Train_Acc: 0.5809, Validation Loss: 0.7619, Val_Acc: 0.5677, counter = 0
# EPOCH 55/100, Train_Loss: 1.2469, Train_Acc: 0.5861, Validation Loss: 0.7530, Val_Acc: 0.5745, counter = 0
# EPOCH 56/100, Train_Loss: 1.2326, Train_Acc: 0.5891, Validation Loss: 0.7448, Val_Acc: 0.5655, counter = 0
# EPOCH 57/100, Train_Loss: 1.2190, Train_Acc: 0.5899, Validation Loss: 0.7370, Val_Acc: 0.5780, counter = 0
# EPOCH 58/100, Train_Loss: 1.2057, Train_Acc: 0.5944, Validation Loss: 0.7286, Val_Acc: 0.5865, counter = 0
# EPOCH 59/100, Train_Loss: 1.1932, Train_Acc: 0.5957, Validation Loss: 0.7214, Val_Acc: 0.5870, counter = 0
# EPOCH 60/100, Train_Loss: 1.1812, Train_Acc: 0.5983, Validation Loss: 0.7151, Val_Acc: 0.5840, counter = 0
# EPOCH 61/100, Train_Loss: 1.1695, Train_Acc: 0.6028, Validation Loss: 0.7077, Val_Acc: 0.5798, counter = 0
# EPOCH 62/100, Train_Loss: 1.1583, Train_Acc: 0.6029, Validation Loss: 0.7018, Val_Acc: 0.5870, counter = 0
# EPOCH 63/100, Train_Loss: 1.1477, Train_Acc: 0.6063, Validation Loss: 0.6959, Val_Acc: 0.5947, counter = 0
# EPOCH 64/100, Train_Loss: 1.1373, Train_Acc: 0.6072, Validation Loss: 0.6894, Val_Acc: 0.5900, counter = 0
# EPOCH 65/100, Train_Loss: 1.1276, Train_Acc: 0.6079, Validation Loss: 0.6837, Val_Acc: 0.5980, counter = 0
# EPOCH 66/100, Train_Loss: 1.1178, Train_Acc: 0.6115, Validation Loss: 0.6778, Val_Acc: 0.5975, counter = 0
# EPOCH 67/100, Train_Loss: 1.1089, Train_Acc: 0.6129, Validation Loss: 0.6724, Val_Acc: 0.5938, counter = 0
# EPOCH 68/100, Train_Loss: 1.0998, Train_Acc: 0.6135, Validation Loss: 0.6685, Val_Acc: 0.6045, counter = 0
# EPOCH 69/100, Train_Loss: 1.0913, Train_Acc: 0.6158, Validation Loss: 0.6632, Val_Acc: 0.6078, counter = 0
# EPOCH 70/100, Train_Loss: 1.0832, Train_Acc: 0.6172, Validation Loss: 0.6575, Val_Acc: 0.6135, counter = 0
# EPOCH 71/100, Train_Loss: 1.0750, Train_Acc: 0.6189, Validation Loss: 0.6538, Val_Acc: 0.6055, counter = 0
# EPOCH 72/100, Train_Loss: 1.0668, Train_Acc: 0.6211, Validation Loss: 0.6484, Val_Acc: 0.6000, counter = 0
# EPOCH 73/100, Train_Loss: 1.0596, Train_Acc: 0.6219, Validation Loss: 0.6439, Val_Acc: 0.6095, counter = 0
# EPOCH 74/100, Train_Loss: 1.0516, Train_Acc: 0.6239, Validation Loss: 0.6397, Val_Acc: 0.6107, counter = 0
# EPOCH 75/100, Train_Loss: 1.0447, Train_Acc: 0.6246, Validation Loss: 0.6361, Val_Acc: 0.6145, counter = 0
# EPOCH 76/100, Train_Loss: 1.0381, Train_Acc: 0.6266, Validation Loss: 0.6317, Val_Acc: 0.6152, counter = 0
# EPOCH 77/100, Train_Loss: 1.0307, Train_Acc: 0.6289, Validation Loss: 0.6274, Val_Acc: 0.6220, counter = 0
# EPOCH 78/100, Train_Loss: 1.0242, Train_Acc: 0.6293, Validation Loss: 0.6233, Val_Acc: 0.6247, counter = 0
# EPOCH 79/100, Train_Loss: 1.0177, Train_Acc: 0.6312, Validation Loss: 0.6194, Val_Acc: 0.6192, counter = 0
# EPOCH 80/100, Train_Loss: 1.0112, Train_Acc: 0.6334, Validation Loss: 0.6158, Val_Acc: 0.6320, counter = 0
# EPOCH 81/100, Train_Loss: 1.0052, Train_Acc: 0.6351, Validation Loss: 0.6125, Val_Acc: 0.6240, counter = 0
# EPOCH 82/100, Train_Loss: 0.9991, Train_Acc: 0.6375, Validation Loss: 0.6087, Val_Acc: 0.6283, counter = 0
# EPOCH 83/100, Train_Loss: 0.9925, Train_Acc: 0.6379, Validation Loss: 0.6055, Val_Acc: 0.6217, counter = 0
# EPOCH 84/100, Train_Loss: 0.9867, Train_Acc: 0.6396, Validation Loss: 0.6015, Val_Acc: 0.6357, counter = 0
# EPOCH 85/100, Train_Loss: 0.9809, Train_Acc: 0.6414, Validation Loss: 0.5983, Val_Acc: 0.6298, counter = 0
# EPOCH 86/100, Train_Loss: 0.9755, Train_Acc: 0.6429, Validation Loss: 0.5946, Val_Acc: 0.6312, counter = 0
# EPOCH 87/100, Train_Loss: 0.9700, Train_Acc: 0.6458, Validation Loss: 0.5916, Val_Acc: 0.6382, counter = 0
# EPOCH 88/100, Train_Loss: 0.9643, Train_Acc: 0.6463, Validation Loss: 0.5884, Val_Acc: 0.6405, counter = 0
# EPOCH 89/100, Train_Loss: 0.9589, Train_Acc: 0.6491, Validation Loss: 0.5851, Val_Acc: 0.6413, counter = 0
# EPOCH 90/100, Train_Loss: 0.9539, Train_Acc: 0.6495, Validation Loss: 0.5819, Val_Acc: 0.6478, counter = 0
# EPOCH 91/100, Train_Loss: 0.9487, Train_Acc: 0.6534, Validation Loss: 0.5790, Val_Acc: 0.6473, counter = 0
# EPOCH 92/100, Train_Loss: 0.9434, Train_Acc: 0.6535, Validation Loss: 0.5755, Val_Acc: 0.6435, counter = 0
# EPOCH 93/100, Train_Loss: 0.9383, Train_Acc: 0.6572, Validation Loss: 0.5731, Val_Acc: 0.6377, counter = 0
# EPOCH 94/100, Train_Loss: 0.9328, Train_Acc: 0.6579, Validation Loss: 0.5698, Val_Acc: 0.6493, counter = 0
# EPOCH 95/100, Train_Loss: 0.9289, Train_Acc: 0.6593, Validation Loss: 0.5666, Val_Acc: 0.6512, counter = 0
# EPOCH 96/100, Train_Loss: 0.9233, Train_Acc: 0.6619, Validation Loss: 0.5639, Val_Acc: 0.6495, counter = 0
# EPOCH 97/100, Train_Loss: 0.9183, Train_Acc: 0.6644, Validation Loss: 0.5606, Val_Acc: 0.6542, counter = 0
# EPOCH 98/100, Train_Loss: 0.9137, Train_Acc: 0.6667, Validation Loss: 0.5580, Val_Acc: 0.6510, counter = 0
# EPOCH 99/100, Train_Loss: 0.9087, Train_Acc: 0.6671, Validation Loss: 0.5551, Val_Acc: 0.6593, counter = 0
# EPOCH 100/100, Train_Loss: 0.9045, Train_Acc: 0.6702, Validation Loss: 0.5520, Val_Acc: 0.6630, counter = 0

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.663
