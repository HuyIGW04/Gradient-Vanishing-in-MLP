# %% [markdown]
# ## **0. Import libraries**

# %%
import torch
import random
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.datasets import FashionMNIST
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
set_seed(SEED)

# %% [markdown]
# ## **1. Prepare dataset**

# %%
batch_size = 512

train_dataset = FashionMNIST(root='data',
                             train=True,
                             transform=transforms.ToTensor(),
                             download=True)
test_dataset = FashionMNIST(root='data',
                            train=False,
                            transform=transforms.ToTensor(),
                            download=True)


# split val and train: random_split
train_ratio = 0.9
train_size = int(len(train_dataset) * train_ratio)
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# dataloader
train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_subset)}")
print(f"Validation size: {len(val_subset)}")
print(f"Test size: {len(test_dataset)}")
# Out:
# Train size: 54000
# Validation size: 6000
# Test size: 10000

# %% [markdown]
# ## **2. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super(MLP, self).__init__()
        self.hidden_dims = hidden_dims
        self.layer1 = nn.Linear(input_dims, hidden_dims)
        self.bn1 = nn.BatchNorm1d(hidden_dims)                # normalize inside Network: batch norm 1d.

        self.layer2 = nn.Linear(hidden_dims, hidden_dims)
        self.bn2 = nn.BatchNorm1d(hidden_dims)

        self.layer3 = nn.Linear(hidden_dims, hidden_dims)
        self.bn3 = nn.BatchNorm1d(hidden_dims)

        self.layer4 = nn.Linear(hidden_dims, hidden_dims)
        self.bn4 = nn.BatchNorm1d(hidden_dims)

        self.layer5 = nn.Linear(hidden_dims, hidden_dims)
        self.bn5 = nn.BatchNorm1d(hidden_dims)

        self.layer6 = nn.Linear(hidden_dims, hidden_dims)
        self.bn6 = nn.BatchNorm1d(hidden_dims)

        self.layer7 = nn.Linear(hidden_dims, hidden_dims)
        self.bn7 = nn.BatchNorm1d(hidden_dims)

        self.output = nn.Linear(hidden_dims, output_dims)

        # tinh chỉnh weight
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.normal_(module.weight, mean=0.0, std=0.05)
                nn.init.constant_(module.bias, 0.0)

    def forward(self, x):
        x = nn.Flatten()(x)

        x = self.layer1(x)
        x = self.bn1(x)
        x = nn.Sigmoid()(x)

        x = self.layer2(x)
        x = self.bn2(x)
        x = nn.Sigmoid()(x)

        x = self.layer3(x)
        x = self.bn3(x)
        x = nn.Sigmoid()(x)

        x = self.layer4(x)
        x = self.bn4(x)
        x = nn.Sigmoid()(x)

        x = self.layer5(x)
        x = self.bn5(x)
        x = nn.Sigmoid()(x)

        x = self.layer6(x)
        x = self.bn6(x)
        x = nn.Sigmoid()(x)

        x = self.layer7(x)
        x = self.bn7(x)
        x = nn.Sigmoid()(x)

        out = self.output(x)

        return out

# %%
input_dims = len(train_subset.__getitem__(0)[0].flatten())
hidden_dims = 128
output_dims = len(train_dataset.classes)
lr = 1e-2

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr)

# %%
class EarlyStopping:
    def __init__(self, max_count=2, epsilon=0.001):
        self.count = 0
        self.loss_prev = np.inf
        self.max_count = max_count
        self.epsilon = epsilon
    
    def earlystopping(self, loss_curr):
        if loss_curr < self.loss_prev:
            self.loss_prev = loss_curr
            self.count = 0
        elif loss_curr > (self.loss_prev + self.epsilon):
            self.count += 1
            if self.count >= self.max_count:
                return True
        return False

# %% [markdown]
# ## **3. Training**

# %%
epochs = 100
train_loss_lst = []
train_acc_lst = []
val_loss_lst = []
val_acc_lst = []

stopper = EarlyStopping(max_count=20, epsilon=0.00001)
for epoch in range(epochs):
    train_loss = 0.0
    train_acc = 0.0
    count = 0

    model.train()
    for X_train, y_train in train_loader:
        X_train, y_train = X_train.to(device), y_train.to(device)
        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_acc += (torch.argmax(outputs, 1) == y_train).sum().item()
        count += len(y_train)

    train_loss /= len(train_loader)
    train_loss_lst.append(train_loss)
    train_acc /= count
    train_acc_lst.append(train_acc)

    val_loss = 0.0
    val_acc = 0.0
    count = 0
    model.eval()
    with torch.no_grad():
        for X_val, y_val in val_loader:
            X_val, y_val = X_val.to(device), y_val.to(device)
            outputs = model(X_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
            val_acc += (torch.argmax(outputs, 1) == y_val).sum().item()
            count += len(y_val)

    val_loss /= len(val_loader)
    val_loss_lst.append(val_loss)
    val_acc /= count
    val_acc_lst.append(val_acc)
    # early stopping
    if stopper.earlystopping(val_loss):
        print(f"Early Stopping at epoch {epoch + 1}, minimum = {val_loss}")
        break

    print(f"EPOCH {epoch+1}/{epochs}, Train_Loss: {train_loss:.4f}, Train_Acc: {train_acc:.4f}, Validation Loss: {val_loss:.4f}, Val_Acc: {val_acc:.4f}, counter = {stopper.count}")
# Out:
# EPOCH 1/100, Train_Loss: 1.9205, Train_Acc: 0.5561, Validation Loss: 1.6695, Val_Acc: 0.6837, counter = 0
# EPOCH 2/100, Train_Loss: 1.5195, Train_Acc: 0.7094, Validation Loss: 1.4012, Val_Acc: 0.7178, counter = 0
# EPOCH 3/100, Train_Loss: 1.2997, Train_Acc: 0.7371, Validation Loss: 1.2240, Val_Acc: 0.7420, counter = 0
# EPOCH 4/100, Train_Loss: 1.1444, Train_Acc: 0.7614, Validation Loss: 1.0916, Val_Acc: 0.7633, counter = 0
# EPOCH 5/100, Train_Loss: 1.0268, Train_Acc: 0.7781, Validation Loss: 0.9875, Val_Acc: 0.7797, counter = 0
# EPOCH 6/100, Train_Loss: 0.9334, Train_Acc: 0.7896, Validation Loss: 0.9061, Val_Acc: 0.7937, counter = 0
# EPOCH 7/100, Train_Loss: 0.8589, Train_Acc: 0.8001, Validation Loss: 0.8410, Val_Acc: 0.8003, counter = 0
# EPOCH 8/100, Train_Loss: 0.7977, Train_Acc: 0.8084, Validation Loss: 0.7877, Val_Acc: 0.8077, counter = 0
# EPOCH 9/100, Train_Loss: 0.7487, Train_Acc: 0.8145, Validation Loss: 0.7408, Val_Acc: 0.8138, counter = 0
# EPOCH 10/100, Train_Loss: 0.7059, Train_Acc: 0.8198, Validation Loss: 0.7054, Val_Acc: 0.8172, counter = 0
# EPOCH 11/100, Train_Loss: 0.6701, Train_Acc: 0.8244, Validation Loss: 0.6726, Val_Acc: 0.8243, counter = 0
# EPOCH 12/100, Train_Loss: 0.6400, Train_Acc: 0.8290, Validation Loss: 0.6426, Val_Acc: 0.8242, counter = 0
# EPOCH 13/100, Train_Loss: 0.6144, Train_Acc: 0.8329, Validation Loss: 0.6214, Val_Acc: 0.8317, counter = 0
# EPOCH 14/100, Train_Loss: 0.5904, Train_Acc: 0.8373, Validation Loss: 0.6025, Val_Acc: 0.8322, counter = 0
# EPOCH 15/100, Train_Loss: 0.5697, Train_Acc: 0.8406, Validation Loss: 0.5821, Val_Acc: 0.8328, counter = 0
# EPOCH 16/100, Train_Loss: 0.5520, Train_Acc: 0.8424, Validation Loss: 0.5655, Val_Acc: 0.8377, counter = 0
# EPOCH 17/100, Train_Loss: 0.5354, Train_Acc: 0.8458, Validation Loss: 0.5526, Val_Acc: 0.8402, counter = 0
# EPOCH 18/100, Train_Loss: 0.5211, Train_Acc: 0.8486, Validation Loss: 0.5345, Val_Acc: 0.8428, counter = 0
# EPOCH 19/100, Train_Loss: 0.5074, Train_Acc: 0.8512, Validation Loss: 0.5300, Val_Acc: 0.8440, counter = 0
# EPOCH 20/100, Train_Loss: 0.4950, Train_Acc: 0.8527, Validation Loss: 0.5155, Val_Acc: 0.8463, counter = 0
# EPOCH 21/100, Train_Loss: 0.4836, Train_Acc: 0.8553, Validation Loss: 0.5050, Val_Acc: 0.8473, counter = 0
# EPOCH 22/100, Train_Loss: 0.4736, Train_Acc: 0.8578, Validation Loss: 0.5012, Val_Acc: 0.8492, counter = 0
# EPOCH 23/100, Train_Loss: 0.4636, Train_Acc: 0.8590, Validation Loss: 0.4931, Val_Acc: 0.8508, counter = 0
# EPOCH 24/100, Train_Loss: 0.4550, Train_Acc: 0.8611, Validation Loss: 0.4778, Val_Acc: 0.8538, counter = 0
# EPOCH 25/100, Train_Loss: 0.4462, Train_Acc: 0.8628, Validation Loss: 0.4756, Val_Acc: 0.8528, counter = 0
# EPOCH 26/100, Train_Loss: 0.4394, Train_Acc: 0.8642, Validation Loss: 0.4637, Val_Acc: 0.8578, counter = 0
# EPOCH 27/100, Train_Loss: 0.4317, Train_Acc: 0.8662, Validation Loss: 0.4521, Val_Acc: 0.8593, counter = 0
# EPOCH 28/100, Train_Loss: 0.4260, Train_Acc: 0.8666, Validation Loss: 0.4605, Val_Acc: 0.8490, counter = 1
# EPOCH 29/100, Train_Loss: 0.4173, Train_Acc: 0.8692, Validation Loss: 0.4423, Val_Acc: 0.8612, counter = 0
# EPOCH 30/100, Train_Loss: 0.4125, Train_Acc: 0.8704, Validation Loss: 0.4455, Val_Acc: 0.8557, counter = 1
# EPOCH 31/100, Train_Loss: 0.4077, Train_Acc: 0.8716, Validation Loss: 0.4336, Val_Acc: 0.8620, counter = 0
# EPOCH 32/100, Train_Loss: 0.4013, Train_Acc: 0.8739, Validation Loss: 0.4351, Val_Acc: 0.8638, counter = 1
# EPOCH 33/100, Train_Loss: 0.3959, Train_Acc: 0.8747, Validation Loss: 0.4502, Val_Acc: 0.8502, counter = 2
# EPOCH 34/100, Train_Loss: 0.3909, Train_Acc: 0.8756, Validation Loss: 0.4255, Val_Acc: 0.8640, counter = 0
# EPOCH 35/100, Train_Loss: 0.3866, Train_Acc: 0.8770, Validation Loss: 0.4170, Val_Acc: 0.8680, counter = 0
# EPOCH 36/100, Train_Loss: 0.3828, Train_Acc: 0.8780, Validation Loss: 0.4179, Val_Acc: 0.8648, counter = 1
# EPOCH 37/100, Train_Loss: 0.3767, Train_Acc: 0.8789, Validation Loss: 0.4142, Val_Acc: 0.8662, counter = 0
# EPOCH 38/100, Train_Loss: 0.3733, Train_Acc: 0.8796, Validation Loss: 0.4219, Val_Acc: 0.8582, counter = 1
# EPOCH 39/100, Train_Loss: 0.3693, Train_Acc: 0.8812, Validation Loss: 0.4150, Val_Acc: 0.8657, counter = 2
# EPOCH 40/100, Train_Loss: 0.3652, Train_Acc: 0.8827, Validation Loss: 0.4032, Val_Acc: 0.8663, counter = 0
# EPOCH 41/100, Train_Loss: 0.3615, Train_Acc: 0.8834, Validation Loss: 0.4116, Val_Acc: 0.8662, counter = 1
# EPOCH 42/100, Train_Loss: 0.3584, Train_Acc: 0.8851, Validation Loss: 0.4665, Val_Acc: 0.8370, counter = 2
# EPOCH 43/100, Train_Loss: 0.3547, Train_Acc: 0.8841, Validation Loss: 0.4048, Val_Acc: 0.8672, counter = 3
# EPOCH 44/100, Train_Loss: 0.3509, Train_Acc: 0.8862, Validation Loss: 0.3912, Val_Acc: 0.8727, counter = 0
# EPOCH 45/100, Train_Loss: 0.3478, Train_Acc: 0.8878, Validation Loss: 0.3947, Val_Acc: 0.8672, counter = 1
# EPOCH 46/100, Train_Loss: 0.3450, Train_Acc: 0.8872, Validation Loss: 0.3826, Val_Acc: 0.8735, counter = 0
# EPOCH 47/100, Train_Loss: 0.3420, Train_Acc: 0.8888, Validation Loss: 0.3842, Val_Acc: 0.8728, counter = 1
# EPOCH 48/100, Train_Loss: 0.3385, Train_Acc: 0.8897, Validation Loss: 0.3884, Val_Acc: 0.8713, counter = 2
# EPOCH 49/100, Train_Loss: 0.3355, Train_Acc: 0.8905, Validation Loss: 0.3954, Val_Acc: 0.8678, counter = 3
# EPOCH 50/100, Train_Loss: 0.3327, Train_Acc: 0.8902, Validation Loss: 0.3912, Val_Acc: 0.8707, counter = 4
# EPOCH 51/100, Train_Loss: 0.3312, Train_Acc: 0.8907, Validation Loss: 0.3845, Val_Acc: 0.8705, counter = 5
# EPOCH 52/100, Train_Loss: 0.3268, Train_Acc: 0.8917, Validation Loss: 0.4238, Val_Acc: 0.8497, counter = 6
# EPOCH 53/100, Train_Loss: 0.3260, Train_Acc: 0.8938, Validation Loss: 0.3781, Val_Acc: 0.8712, counter = 0
# EPOCH 54/100, Train_Loss: 0.3233, Train_Acc: 0.8945, Validation Loss: 0.3680, Val_Acc: 0.8715, counter = 0
# EPOCH 55/100, Train_Loss: 0.3189, Train_Acc: 0.8953, Validation Loss: 0.4038, Val_Acc: 0.8528, counter = 1
# EPOCH 56/100, Train_Loss: 0.3182, Train_Acc: 0.8944, Validation Loss: 0.4036, Val_Acc: 0.8597, counter = 2
# EPOCH 57/100, Train_Loss: 0.3142, Train_Acc: 0.8961, Validation Loss: 0.3744, Val_Acc: 0.8703, counter = 3
# EPOCH 58/100, Train_Loss: 0.3108, Train_Acc: 0.8971, Validation Loss: 0.4185, Val_Acc: 0.8553, counter = 4
# EPOCH 59/100, Train_Loss: 0.3088, Train_Acc: 0.8979, Validation Loss: 0.3697, Val_Acc: 0.8735, counter = 5
# EPOCH 60/100, Train_Loss: 0.3095, Train_Acc: 0.8970, Validation Loss: 0.3793, Val_Acc: 0.8693, counter = 6
# EPOCH 61/100, Train_Loss: 0.3059, Train_Acc: 0.8971, Validation Loss: 0.3634, Val_Acc: 0.8728, counter = 0
# EPOCH 62/100, Train_Loss: 0.3020, Train_Acc: 0.9001, Validation Loss: 0.3711, Val_Acc: 0.8743, counter = 1
# EPOCH 63/100, Train_Loss: 0.2992, Train_Acc: 0.9010, Validation Loss: 0.3988, Val_Acc: 0.8583, counter = 2
# EPOCH 64/100, Train_Loss: 0.2981, Train_Acc: 0.9003, Validation Loss: 0.3674, Val_Acc: 0.8710, counter = 3
# EPOCH 65/100, Train_Loss: 0.2962, Train_Acc: 0.9021, Validation Loss: 0.3636, Val_Acc: 0.8737, counter = 4
# EPOCH 66/100, Train_Loss: 0.2946, Train_Acc: 0.9016, Validation Loss: 0.3962, Val_Acc: 0.8675, counter = 5
# EPOCH 67/100, Train_Loss: 0.2922, Train_Acc: 0.9027, Validation Loss: 0.3583, Val_Acc: 0.8730, counter = 0
# EPOCH 68/100, Train_Loss: 0.2892, Train_Acc: 0.9037, Validation Loss: 0.3725, Val_Acc: 0.8698, counter = 1
# EPOCH 69/100, Train_Loss: 0.2875, Train_Acc: 0.9040, Validation Loss: 0.3893, Val_Acc: 0.8690, counter = 2
# EPOCH 70/100, Train_Loss: 0.2864, Train_Acc: 0.9038, Validation Loss: 0.3717, Val_Acc: 0.8758, counter = 3
# EPOCH 71/100, Train_Loss: 0.2846, Train_Acc: 0.9057, Validation Loss: 0.3828, Val_Acc: 0.8677, counter = 4
# EPOCH 72/100, Train_Loss: 0.2830, Train_Acc: 0.9050, Validation Loss: 0.3727, Val_Acc: 0.8657, counter = 5
# EPOCH 73/100, Train_Loss: 0.2814, Train_Acc: 0.9066, Validation Loss: 0.3623, Val_Acc: 0.8725, counter = 6
# EPOCH 74/100, Train_Loss: 0.2788, Train_Acc: 0.9065, Validation Loss: 0.3534, Val_Acc: 0.8738, counter = 0
# EPOCH 75/100, Train_Loss: 0.2756, Train_Acc: 0.9071, Validation Loss: 0.3545, Val_Acc: 0.8720, counter = 1
# EPOCH 76/100, Train_Loss: 0.2743, Train_Acc: 0.9082, Validation Loss: 0.3468, Val_Acc: 0.8790, counter = 0
# EPOCH 77/100, Train_Loss: 0.2721, Train_Acc: 0.9099, Validation Loss: 0.3659, Val_Acc: 0.8742, counter = 1
# EPOCH 78/100, Train_Loss: 0.2717, Train_Acc: 0.9098, Validation Loss: 0.3515, Val_Acc: 0.8760, counter = 2
# EPOCH 79/100, Train_Loss: 0.2682, Train_Acc: 0.9104, Validation Loss: 0.3623, Val_Acc: 0.8743, counter = 3
# EPOCH 80/100, Train_Loss: 0.2688, Train_Acc: 0.9109, Validation Loss: 0.3741, Val_Acc: 0.8660, counter = 4
# EPOCH 81/100, Train_Loss: 0.2666, Train_Acc: 0.9101, Validation Loss: 0.3738, Val_Acc: 0.8670, counter = 5
# EPOCH 82/100, Train_Loss: 0.2651, Train_Acc: 0.9120, Validation Loss: 0.3507, Val_Acc: 0.8767, counter = 6
# EPOCH 83/100, Train_Loss: 0.2617, Train_Acc: 0.9124, Validation Loss: 0.3756, Val_Acc: 0.8655, counter = 7
# EPOCH 84/100, Train_Loss: 0.2601, Train_Acc: 0.9130, Validation Loss: 0.3783, Val_Acc: 0.8690, counter = 8
# EPOCH 85/100, Train_Loss: 0.2567, Train_Acc: 0.9152, Validation Loss: 0.3462, Val_Acc: 0.8735, counter = 0
# EPOCH 86/100, Train_Loss: 0.2581, Train_Acc: 0.9139, Validation Loss: 0.4038, Val_Acc: 0.8565, counter = 1
# EPOCH 87/100, Train_Loss: 0.2567, Train_Acc: 0.9139, Validation Loss: 0.3818, Val_Acc: 0.8643, counter = 2
# EPOCH 88/100, Train_Loss: 0.2538, Train_Acc: 0.9157, Validation Loss: 0.3812, Val_Acc: 0.8618, counter = 3
# EPOCH 89/100, Train_Loss: 0.2528, Train_Acc: 0.9150, Validation Loss: 0.3477, Val_Acc: 0.8777, counter = 4
# EPOCH 90/100, Train_Loss: 0.2510, Train_Acc: 0.9151, Validation Loss: 0.3419, Val_Acc: 0.8765, counter = 0
# EPOCH 91/100, Train_Loss: 0.2492, Train_Acc: 0.9168, Validation Loss: 0.3394, Val_Acc: 0.8787, counter = 0
# EPOCH 92/100, Train_Loss: 0.2454, Train_Acc: 0.9178, Validation Loss: 0.3400, Val_Acc: 0.8807, counter = 1
# EPOCH 93/100, Train_Loss: 0.2451, Train_Acc: 0.9176, Validation Loss: 0.3678, Val_Acc: 0.8660, counter = 2
# EPOCH 94/100, Train_Loss: 0.2443, Train_Acc: 0.9196, Validation Loss: 0.3706, Val_Acc: 0.8697, counter = 3
# EPOCH 95/100, Train_Loss: 0.2410, Train_Acc: 0.9211, Validation Loss: 0.3524, Val_Acc: 0.8795, counter = 4
# EPOCH 96/100, Train_Loss: 0.2406, Train_Acc: 0.9200, Validation Loss: 0.3358, Val_Acc: 0.8792, counter = 0
# EPOCH 97/100, Train_Loss: 0.2391, Train_Acc: 0.9202, Validation Loss: 0.3656, Val_Acc: 0.8745, counter = 1
# EPOCH 98/100, Train_Loss: 0.2392, Train_Acc: 0.9203, Validation Loss: 0.3611, Val_Acc: 0.8742, counter = 2
# EPOCH 99/100, Train_Loss: 0.2368, Train_Acc: 0.9204, Validation Loss: 0.3608, Val_Acc: 0.8803, counter = 3
# EPOCH 100/100, Train_Loss: 0.2356, Train_Acc: 0.9222, Validation Loss: 0.3393, Val_Acc: 0.8780, counter = 4

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_loss_lst, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_loss_lst, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_acc_lst, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_acc_lst, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %% [markdown]
# ## **4. Evaluation**

# %%
val_target = []
val_predict = []

model.eval()
with torch.no_grad():
    for X_val, y_val in val_loader:
        X_val = X_val.to(device)
        y_val = y_val.to(device)
        outputs = model(X_val)

        val_predict.append(outputs.cpu())
        val_target.append(y_val.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = (torch.argmax(val_predict, 1) == val_target).sum().item() / len(val_target)

    print('Evaluation on val set:')
    print(f'Accuracy: {val_acc}')
# Out:
# Evaluation on val set:
# Accuracy: 0.878
